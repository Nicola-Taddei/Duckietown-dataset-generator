# %%
# !rm -rf saved_model
# !python benchmark.py #The benchmark also saves the model for ONNX
# Out:
# WARNING:tensorflow:From /home/raphael/anaconda3/envs/tf1/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /home/raphael/anaconda3/envs/tf1/lib/python3.6/site-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/raphael/MILA/duckie_ift6757/mobile-segmentation/core/shufflenet_v2.py:15: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# 2020-12-06 15:56:17.217794: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-12-06 15:56:17.241103: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3600000000 Hz
# 2020-12-06 15:56:17.241405: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5569f3f80760 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-06 15:56:17.241424: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-12-06 15:56:17.242001: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-06 15:56:17.250554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-06 15:56:17.250572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]
# 2020-12-06 15:56:17.299082: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-06 15:56:17.299496: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5569f3f7e220 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-12-06 15:56:17.299510: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 1070 Ti, Compute Capability 6.1
# INFO:tensorflow:Restoring parameters from ./logs/model.ckpt-6220
# WARNING:tensorflow:From benchmark.py:65: simple_save (from tensorflow.python.saved_model.simple_save) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.simple_save.
# WARNING:tensorflow:From /home/raphael/anaconda3/envs/tf1/lib/python3.6/site-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: saved_model/saved_model.pb
# avg fps: 35.913958994095005, avg inference time: 2.7844326496124268e-05 ms

# %%
# !python -m tf2onnx.convert --saved-model ./saved_model --output ./output/segmentation.onnx --opset 7
# Out:
# WARNING:tensorflow:From /home/raphael/anaconda3/envs/tf1/lib/python3.6/site-packages/tf2onnx/verbose_logging.py:76: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2020-12-06 15:56:51,342 - WARNING - From /home/raphael/anaconda3/envs/tf1/lib/python3.6/site-packages/tf2onnx/verbose_logging.py:76: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2020-12-06 15:56:51,463 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2020-12-06 15:56:53,071 - INFO - Using tensorflow=1.15.0, onnx=1.8.0, tf2onnx=1.7.2/995bd6
# 2020-12-06 15:56:53,071 - INFO - Using opset <onnx, 7>
# 2020-12-06 15:56:54,665 - INFO - Computed 319 values for constant folding
# 2020-12-06 15:56:54,908 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Conv1/weights/read
# 2020-12-06 15:56:54,908 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Conv1/batch_norm/gamma/read
# 2020-12-06 15:56:54,908 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Conv1/batch_norm/beta/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Conv1/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Conv1/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_before/weights/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,909 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_after/weights/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,910 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/conv1x1_after/weights/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,911 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_1/second_branch/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage2/unit_2/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage2/unit_2/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_before/weights/read
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,912 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_after/weights/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_2/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage2/unit_3/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,913 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage2/unit_3/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_before/weights/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,914 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_after/weights/read
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_3/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage2/unit_4/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage2/unit_4/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_before/weights/read
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,915 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,916 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,916 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,916 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,916 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,916 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,916 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,916 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_after/weights/read
# 2020-12-06 15:56:54,916 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage2/unit_4/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_before/weights/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,917 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_after/weights/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,918 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/conv1x1_after/weights/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_1/second_branch/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_2/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,919 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_2/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_before/weights/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,920 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_after/weights/read
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_2/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_3/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_3/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_before/weights/read
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,921 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_after/weights/read
# 2020-12-06 15:56:54,922 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_3/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_4/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_4/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_before/weights/read
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,923 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_after/weights/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,924 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_4/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_5/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_5/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_before/weights/read
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,925 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_after/weights/read
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_5/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_6/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_6/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,926 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/weights/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,927 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/weights/read
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_7/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_7/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/weights/read
# 2020-12-06 15:56:54,928 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/weights/read
# 2020-12-06 15:56:54,929 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_8/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_8/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/weights/read
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,930 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/weights/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,931 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,932 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,932 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/weights/read
# 2020-12-06 15:56:54,932 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,932 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,933 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,933 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,933 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,933 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,933 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,933 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,933 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,933 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/weights/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,934 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,935 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/weights/read
# 2020-12-06 15:56:54,935 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,935 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,935 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,935 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,935 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_2/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,935 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_2/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,935 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/weights/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,936 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/weights/read
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_3/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_3/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/weights/read
# 2020-12-06 15:56:54,937 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,938 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/weights/read
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_4/concat_shuffle_split/Reshape/shape
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_4/concat_shuffle_split/Reshape_1/shape
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/weights/read
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/batch_norm/gamma/read
# 2020-12-06 15:56:54,939 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/batch_norm/beta/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/depthwise_weights/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/batch_norm/gamma/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/batch_norm/beta/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/weights/read
# 2020-12-06 15:56:54,940 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/batch_norm/gamma/read
# 2020-12-06 15:56:54,941 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/batch_norm/beta/read
# 2020-12-06 15:56:54,941 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-06 15:56:54,941 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-06 15:56:54,941 - INFO - folding node using tf type=Identity, name=image_pooling/weights/read
# 2020-12-06 15:56:54,941 - INFO - folding node using tf type=Identity, name=image_pooling/BatchNorm/gamma/read
# 2020-12-06 15:56:54,941 - INFO - folding node using tf type=Identity, name=image_pooling/BatchNorm/beta/read
# 2020-12-06 15:56:54,941 - INFO - folding node using tf type=Identity, name=image_pooling/BatchNorm/moving_mean/read
# 2020-12-06 15:56:54,941 - INFO - folding node using tf type=Identity, name=image_pooling/BatchNorm/moving_variance/read
# 2020-12-06 15:56:54,942 - INFO - folding node using tf type=Identity, name=aspp0/weights/read
# 2020-12-06 15:56:54,942 - INFO - folding node using tf type=Identity, name=aspp0/BatchNorm/gamma/read
# 2020-12-06 15:56:54,942 - INFO - folding node using tf type=Identity, name=aspp0/BatchNorm/beta/read
# 2020-12-06 15:56:54,942 - INFO - folding node using tf type=Identity, name=aspp0/BatchNorm/moving_mean/read
# 2020-12-06 15:56:54,942 - INFO - folding node using tf type=Identity, name=aspp0/BatchNorm/moving_variance/read
# 2020-12-06 15:56:54,942 - INFO - folding node using tf type=Identity, name=concat_projection/weights/read
# 2020-12-06 15:56:54,942 - INFO - folding node using tf type=Identity, name=concat_projection/BatchNorm/gamma/read
# 2020-12-06 15:56:54,942 - INFO - folding node using tf type=Identity, name=concat_projection/BatchNorm/beta/read
# 2020-12-06 15:56:54,943 - INFO - folding node using tf type=Identity, name=concat_projection/BatchNorm/moving_mean/read
# 2020-12-06 15:56:54,943 - INFO - folding node using tf type=Identity, name=concat_projection/BatchNorm/moving_variance/read
# 2020-12-06 15:56:54,943 - INFO - folding node using tf type=Identity, name=logits/semantic/weights/read
# 2020-12-06 15:56:54,943 - INFO - folding node using tf type=Identity, name=logits/semantic/biases/read
# 2020-12-06 15:56:54,943 - INFO - folding node using tf type=StridedSlice, name=strided_slice
# 2020-12-06 15:56:55,146 - INFO - Optimizing ONNX model
# 2020-12-06 15:56:55,798 - INFO - After optimization: BatchNormalization -39 (58->19), Cast -26 (26->0), Const -184 (367->183), Identity -2 (2->0), Transpose -203 (257->54), Upsample -1 (3->2)
# 2020-12-06 15:56:55,817 - INFO -
# 2020-12-06 15:56:55,817 - INFO - Successfully converted TensorFlow model ./saved_model to ONNX
# 2020-12-06 15:56:55,823 - INFO - ONNX model is saved at ./output/segmentation.onnx
