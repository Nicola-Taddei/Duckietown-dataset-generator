# %%
# !rm -rf saved_model
# !python export.py #The export script also benchmarks the model
# Out:
# WARNING:tensorflow:From /home/raphael/anaconda3/envs/tf1/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /home/raphael/anaconda3/envs/tf1/lib/python3.6/site-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/raphael/MILA/duckie_ift6757/mobile-segmentation/core/shufflenet_v2.py:15: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# 2020-12-21 21:51:59.692374: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-12-21 21:51:59.713704: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3600000000 Hz
# 2020-12-21 21:51:59.713980: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563850035f80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-21 21:51:59.713999: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-12-21 21:51:59.714644: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-21 21:51:59.723169: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-21 21:51:59.723189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]
# 2020-12-21 21:51:59.779364: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-21 21:51:59.779762: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56384e780200 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-12-21 21:51:59.779783: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 1070 Ti, Compute Capability 6.1
# INFO:tensorflow:Restoring parameters from ./logs/model.ckpt-12360
# WARNING:tensorflow:From export.py:65: simple_save (from tensorflow.python.saved_model.simple_save) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.simple_save.
# WARNING:tensorflow:From /home/raphael/anaconda3/envs/tf1/lib/python3.6/site-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: saved_model/saved_model.pb
# avg fps: 31.957290964826132, avg inference time: 3.129176378250122e-05 ms

# %%
# !python -m tf2onnx.convert --saved-model ./saved_model --output ./output/segmentation.onnx --opset 7
# Out:
# shape/shape
# 2020-12-19 12:22:35,392 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_6/concat_shuffle_split/Reshape_1/shape
# 2020-12-19 12:22:35,392 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/weights/read
# 2020-12-19 12:22:35,392 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/batch_norm/gamma/read
# 2020-12-19 12:22:35,392 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/batch_norm/beta/read
# 2020-12-19 12:22:35,392 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,392 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/depthwise_weights/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/batch_norm/gamma/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/batch_norm/beta/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/depthwise/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/weights/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/batch_norm/gamma/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/batch_norm/beta/read
# 2020-12-19 12:22:35,393 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_6/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_7/concat_shuffle_split/Reshape/shape
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_7/concat_shuffle_split/Reshape_1/shape
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/weights/read
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/batch_norm/gamma/read
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/batch_norm/beta/read
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,394 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/depthwise_weights/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/batch_norm/gamma/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/batch_norm/beta/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/depthwise/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/weights/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/batch_norm/gamma/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/batch_norm/beta/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_7/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,395 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_8/concat_shuffle_split/Reshape/shape
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage3/unit_8/concat_shuffle_split/Reshape_1/shape
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/weights/read
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/batch_norm/gamma/read
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/batch_norm/beta/read
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/depthwise_weights/read
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/batch_norm/gamma/read
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/batch_norm/beta/read
# 2020-12-19 12:22:35,396 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,397 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/depthwise/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,397 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/weights/read
# 2020-12-19 12:22:35,397 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/batch_norm/gamma/read
# 2020-12-19 12:22:35,397 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/batch_norm/beta/read
# 2020-12-19 12:22:35,397 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,397 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage3/unit_8/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,397 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/weights/read
# 2020-12-19 12:22:35,397 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/batch_norm/gamma/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/batch_norm/beta/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/depthwise_weights/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/batch_norm/gamma/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/batch_norm/beta/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/depthwise/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,398 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/weights/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/batch_norm/gamma/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/batch_norm/beta/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/depthwise_weights/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/batch_norm/gamma/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/batch_norm/beta/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/depthwise/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,399 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/weights/read
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/batch_norm/gamma/read
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/batch_norm/beta/read
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_1/second_branch/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_2/concat_shuffle_split/Reshape/shape
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_2/concat_shuffle_split/Reshape_1/shape
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/weights/read
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/batch_norm/gamma/read
# 2020-12-19 12:22:35,400 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/batch_norm/beta/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/depthwise_weights/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/batch_norm/gamma/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/batch_norm/beta/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/depthwise/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/weights/read
# 2020-12-19 12:22:35,401 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/batch_norm/gamma/read
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/batch_norm/beta/read
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_2/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_3/concat_shuffle_split/Reshape/shape
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_3/concat_shuffle_split/Reshape_1/shape
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/weights/read
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/batch_norm/gamma/read
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/batch_norm/beta/read
# 2020-12-19 12:22:35,402 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/depthwise_weights/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/batch_norm/gamma/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/batch_norm/beta/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/depthwise/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/weights/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/batch_norm/gamma/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/batch_norm/beta/read
# 2020-12-19 12:22:35,403 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_3/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_4/concat_shuffle_split/Reshape/shape
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Pack, name=ShuffleNetV2/Stage4/unit_4/concat_shuffle_split/Reshape_1/shape
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/weights/read
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/batch_norm/gamma/read
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/batch_norm/beta/read
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_before/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,404 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/depthwise_weights/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/batch_norm/gamma/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/batch_norm/beta/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/depthwise/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/weights/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/batch_norm/gamma/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/batch_norm/beta/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/batch_norm/moving_mean/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=ShuffleNetV2/Stage4/unit_4/conv1x1_after/batch_norm/moving_variance/read
# 2020-12-19 12:22:35,405 - INFO - folding node using tf type=Identity, name=image_pooling/weights/read
# 2020-12-19 12:22:35,406 - INFO - folding node using tf type=Identity, name=image_pooling/BatchNorm/gamma/read
# 2020-12-19 12:22:35,406 - INFO - folding node using tf type=Identity, name=image_pooling/BatchNorm/beta/read
# 2020-12-19 12:22:35,406 - INFO - folding node using tf type=Identity, name=image_pooling/BatchNorm/moving_mean/read
# 2020-12-19 12:22:35,406 - INFO - folding node using tf type=Identity, name=image_pooling/BatchNorm/moving_variance/read
# 2020-12-19 12:22:35,406 - INFO - folding node using tf type=Identity, name=aspp0/weights/read
# 2020-12-19 12:22:35,406 - INFO - folding node using tf type=Identity, name=aspp0/BatchNorm/gamma/read
# 2020-12-19 12:22:35,406 - INFO - folding node using tf type=Identity, name=aspp0/BatchNorm/beta/read
# 2020-12-19 12:22:35,407 - INFO - folding node using tf type=Identity, name=aspp0/BatchNorm/moving_mean/read
# 2020-12-19 12:22:35,407 - INFO - folding node using tf type=Identity, name=aspp0/BatchNorm/moving_variance/read
# 2020-12-19 12:22:35,407 - INFO - folding node using tf type=Identity, name=concat_projection/weights/read
# 2020-12-19 12:22:35,407 - INFO - folding node using tf type=Identity, name=concat_projection/BatchNorm/gamma/read
# 2020-12-19 12:22:35,407 - INFO - folding node using tf type=Identity, name=concat_projection/BatchNorm/beta/read
# 2020-12-19 12:22:35,407 - INFO - folding node using tf type=Identity, name=concat_projection/BatchNorm/moving_mean/read
# 2020-12-19 12:22:35,407 - INFO - folding node using tf type=Identity, name=concat_projection/BatchNorm/moving_variance/read
# 2020-12-19 12:22:35,407 - INFO - folding node using tf type=Identity, name=logits/semantic/weights/read
# 2020-12-19 12:22:35,408 - INFO - folding node using tf type=Identity, name=logits/semantic/biases/read
# 2020-12-19 12:22:35,408 - INFO - folding node using tf type=StridedSlice, name=strided_slice
# 2020-12-19 12:22:35,666 - INFO - Optimizing ONNX model
# 2020-12-19 12:22:36,377 - INFO - After optimization: BatchNormalization -39 (58->19), Cast -26 (26->0), Const -184 (367->183), Identity -2 (2->0), Transpose -203 (257->54), Upsample -1 (3->2)
# 2020-12-19 12:22:36,397 - INFO -
# 2020-12-19 12:22:36,397 - INFO - Successfully converted TensorFlow model ./saved_model to ONNX
# 2020-12-19 12:22:36,402 - INFO - ONNX model is saved at ./output/segmentation.onnx
